# %%
import os
import sqlite3
import pandas as pd
import json
import re  # Import the re module for regular expressions

# Path where files are located
files_directory = r'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3'

# Define participant labels to delete
participant_labels_to_delete = {'evgeny', 'jmgodber', 'csaxman', 'sas14', 'bouwman'}

# List to store files to be deleted
files_to_delete = []

# List to store files remaining after deletion
remaining_files = []

# Function to rename files by adding .sqlite extension
def add_sqlite_extension(file_path):
    if not file_path.endswith('.sqlite'):
        new_file_path = file_path + '.sqlite'
        os.rename(file_path, new_file_path)
        print(f"Renamed '{file_path}' to '{new_file_path}'")
        return new_file_path
    return file_path

# Function to safely extract JSON data
def safe_from_json(json_string):
    try:
        return json.loads(json_string)
    except json.JSONDecodeError:
        print("Error decoding JSON.")
        return None

# Function to extract text from JSON
def extract_text_from_json(json_data):
    extracted_text = []
    def extract_text(obj):
        if isinstance(obj, dict):
            for k, v in obj.items():
                if k == 'text':
                    extracted_text.append(v)
                extract_text(v)
        elif isinstance(obj, list):
            for item in obj:
                extract_text(item)
    extract_text(json_data)
    return '\n'.join(extracted_text)

# DataFrame to combine results
combined_df = pd.DataFrame()

# Process each file in the directory
for filename in os.listdir(files_directory):
    file_path = os.path.join(files_directory, filename)
    
    if os.path.isfile(file_path):
        # Rename the file by adding .sqlite extension if needed
        new_file_path = add_sqlite_extension(file_path)
        
        # Connect to the SQLite database
        try:
            conn = sqlite3.connect(new_file_path)
            c = conn.cursor()

            # Query the 'props' table to get the 'value' for 'metadata'
            metadata_query = "SELECT value FROM props WHERE name = 'metadata'"
            metadata_df = pd.read_sql_query(metadata_query, conn)
            
            # Check if 'metadata_df' has data
            if metadata_df.empty:
                print("No metadata found in 'props' table.")
                conn.close()
                continue
            
            # Extract the participant 'netid' from the 'metadata'
            metadata_value = metadata_df['value'][0]  # Assuming only one entry for metadata
            metadata = safe_from_json(metadata_value)
            if metadata is None:
                print("Error extracting participant from metadata.")
                conn.close()
                continue
            participant = metadata.get('participant', 'Unknown')
            
            # Query the 'document' table to get the 'final' JSON information
            document_query = "SELECT json FROM document WHERE kind = 'final'"
            document_df = pd.read_sql_query(document_query, conn)
            
            # Check if 'document_df' has data
            if document_df.empty:
                print("No final JSON information found in 'document' table.")
                conn.close()
                continue
            
            # Extract the 'final' JSON information
            final_json = document_df['json'][0]  # Assuming only one entry for final
            
            # Extract text using the function
            extracted_text = extract_text_from_json(safe_from_json(final_json))
            
            # Create a data frame with participant and extracted text
            temp_df = pd.DataFrame({
                'file_path': [new_file_path],
                'participant': [participant],
                'extracted_text': [extracted_text]
            })
            
            # Combine with the main DataFrame
            combined_df = pd.concat([combined_df, temp_df], ignore_index=True)

            conn.close()
        
        except sqlite3.Error as e:
            print(f"Error accessing SQLite file {new_file_path}: {e}")
        except json.JSONDecodeError:
            print(f"Error decoding JSON in file {new_file_path}")

# Retain only the file with the most text for each participant
if not combined_df.empty:
    combined_df['text_length'] = combined_df['extracted_text'].apply(len)
    
# Group by participant and find the index of the max text length
    max_text_length_df = combined_df.loc[combined_df.groupby('participant')['text_length'].idxmax()]
    
    # Create a set of file paths to keep
    remaining_files = set(max_text_length_df['file_path'])
    
    # Identify files to delete (all other files for each participant)
    for index, row in combined_df.iterrows():
        if row['file_path'] not in remaining_files or row['participant'] in participant_labels_to_delete:
            files_to_delete.append(row['file_path'])

# Remove duplicates from files_to_delete
files_to_delete = list(set(files_to_delete))

# Delete the identified files
for file_path in files_to_delete:
    try:
        os.remove(file_path)
        print(f"Deleted file: {file_path}")
    except IOError:
        print(f"Error deleting file: {file_path}")

# Perform additional SQL operations on remaining files
for filename in os.listdir(files_directory):
    file_path = os.path.join(files_directory, filename)
    
    if os.path.isfile(file_path):
        new_file_path = add_sqlite_extension(file_path)
        
        try:
            conn = sqlite3.connect(new_file_path)
            c = conn.cursor()

            # Update metadata to replace participant with an empty string
            c.execute("SELECT value FROM props WHERE name='metadata'")
            metadata_row = c.fetchone()
            if metadata_row:
                metadata_value = metadata_row[0]
                try:
                    metadata_json = json.loads(metadata_value)
                    metadata_json['participant'] = ""
                    new_metadata_value = json.dumps(metadata_json)
                    c.execute("UPDATE props SET value=? WHERE name='metadata'", (new_metadata_value,))
                except json.JSONDecodeError:
                    print(f"Error decoding JSON for file: {filename}. Value: {metadata_value}")
        
            # Update config to replace label with an empty string (if applicable)
            c.execute("SELECT value FROM props WHERE name='config'")
            config_row = c.fetchone()
            if config_row:
                config_value = config_row[0]
                try:
                    config_json = json.loads(config_value)
                    config_json['label'] = ""
                    new_config_value = json.dumps(config_json)
                    c.execute("UPDATE props SET value=? WHERE name='config'", (new_config_value,))
                except json.JSONDecodeError:
                    print(f"Error decoding JSON for file: {filename}. Value: {config_value}")

            # Clear tabs
            c.execute("UPDATE act SET json='{\"is_focused\":false}' WHERE k='focus' AND json LIKE '%is_focused\":false%'")

            conn.commit()
            conn.close()
        
        except sqlite3.Error as e:
            print(f"Error accessing SQLite file {new_file_path}: {e}")

# Rename log files after processing
for filename in os.listdir(files_directory):
    file_path = os.path.join(files_directory, filename)
    
    if os.path.isfile(file_path):
        current_name = file_path
        new_name = re.sub(r"(\d+)(-\w+)(-\w+)(.sqlite)", r"7399\2\3", filename)
        new_file_path = os.path.join(files_directory, new_name)
        try:
            os.rename(current_name, new_file_path)
            print(f"Renamed '{current_name}' to '{new_file_path}'")
        except Exception as e:
            print(f"Skipping {current_name} - unable to rename file ({e})")

print("All specified operations are complete.")
# Out:
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3eiymbu-0xp5jiBpdI' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3eiymbu-0xp5jiBpdI.sqlite'
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3eiyogy-V88kCZA8PX' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3eiyogy-V88kCZA8PX.sqlite'
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3eiyz5p-JWFtYxC3Iz' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3eiyz5p-JWFtYxC3Iz.sqlite'
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3eizo2a-pImzTCWsZI' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3eizo2a-pImzTCWsZI.sqlite'
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3ej12ip-r95wPzmA17' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3ej12ip-r95wPzmA17.sqlite'
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3ej156r-duErjhvB31' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3ej156r-duErjhvB31.sqlite'
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3ej902f-6hhAGLT692' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3ej902f-6hhAGLT692.sqlite'
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3ejac8x-UjXCKYPsEm' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3ejac8x-UjXCKYPsEm.sqlite'
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3elacrk-PTmLDCIw42' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3elacrk-PTmLDCIw42.sqlite'
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3em41cj-PBTEckSJ5b' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3em41cj-PBTEckSJ5b.sqlite'
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3em462m-peAU7AP5jo' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3em462m-peAU7AP5jo.sqlite'
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3em4658-Wy8adTzqjd' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3em4658-Wy8adTzqjd.sqlite'
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3em46ka-zczbvUtDGT' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3em46ka-zczbvUtDGT.sqlite'
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3em472r-q3DhZUD2m0' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3em472r-q3DhZUD2m0.sqlite'
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3em477k-SV1Jok6QWh' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3em477k-SV1Jok6QWh.sqlite'
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3em4d5r-cOgJpoyZt8' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3em4d5r-cOgJpoyZt8.sqlite'
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3em94jn-IBVyhhvCE0' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3em94jn-IBVyhhvCE0.sqlite'
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3emhmpl-GFmekIOj5V' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3emhmpl-GFmekIOj5V.sqlite'
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3emlh6o-5KPM5OQ5mS' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3emlh6o-5KPM5OQ5mS.sqlite'
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3epbo6p-NOhT7IfbNZ' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3epbo6p-NOhT7IfbNZ.sqlite'
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3epbqu7-JSLeIr0XQe' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3epbqu7-JSLeIr0XQe.sqlite'
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3epbr8x-6duPHYrVZp' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3epbr8x-6duPHYrVZp.sqlite'
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3epbro3-T4U1KPViPO' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3epbro3-T4U1KPViPO.sqlite'
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3epbsfk-ridsrS8whP' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3epbsfk-ridsrS8whP.sqlite'
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3epbwqu-uvPJbrZrzQ' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3epbwqu-uvPJbrZrzQ.sqlite'
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3epdanu-xSdBgQ3YhK' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3epdanu-xSdBgQ3YhK.sqlite'
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3epmdhz-ZMyLB27s5X' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3epmdhz-ZMyLB27s5X.sqlite'
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3ezeaov-QjguzOTwHc' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3ezeaov-QjguzOTwHc.sqlite'
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3ezeofn-6pHlzJZ6r9' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3ezeofn-6pHlzJZ6r9.sqlite'
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3ezeons-dHVi0TtuGA' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3ezeons-dHVi0TtuGA.sqlite'
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3ezepfm-5OxUw08tUT' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3ezepfm-5OxUw08tUT.sqlite'
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3ezeprq-4btQbTSLKG' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3ezeprq-4btQbTSLKG.sqlite'
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3ezeq5v-vgdq6SUA9R' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3ezeq5v-vgdq6SUA9R.sqlite'
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3ezetpw-8FFUnG1Jp7' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3ezetpw-8FFUnG1Jp7.sqlite'
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3ezhv8l-GEjtLEela7' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3ezhv8l-GEjtLEela7.sqlite'
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3ezm4ad-XzX7pRFZhh' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3ezm4ad-XzX7pRFZhh.sqlite'
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3eznjxq-gMs5vLJHb5' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3eznjxq-gMs5vLJHb5.sqlite'
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3ezsnhm-a7GYEzZPNf' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3ezsnhm-a7GYEzZPNf.sqlite'
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3ezxdzn-6VtYbF8hpE' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3ezxdzn-6VtYbF8hpE.sqlite'
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3f0i4yx-QVn4tjBF7N' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3f0i4yx-QVn4tjBF7N.sqlite'
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3hdsc0k-YDtivu7Ods' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3hdsc0k-YDtivu7Ods.sqlite'
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3hdsosk-3IkdMFfjhn' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3hdsosk-3IkdMFfjhn.sqlite'
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3hdsp0f-vWPi61W6pM' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3hdsp0f-vWPi61W6pM.sqlite'
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3hdsp89-JNds0qY5Zr' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3hdsp89-JNds0qY5Zr.sqlite'
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3hdw736-wb5NwbmFfO' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3hdw736-wb5NwbmFfO.sqlite'
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3hdwune-tEbxHBTKAu' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3hdwune-tEbxHBTKAu.sqlite'
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3hh0ie9-pplhA1VbMu' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3hh0ie9-pplhA1VbMu.sqlite'
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3hh0iii-LeWRZMBN6h' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3hh0iii-LeWRZMBN6h.sqlite'
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3hh0imo-1BbY8bTQLj' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3hh0imo-1BbY8bTQLj.sqlite'
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3hh0ivg-uQbIWsBBSd' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3hh0ivg-uQbIWsBBSd.sqlite'
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3hh0j5j-vFjcpMmfAq' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3hh0j5j-vFjcpMmfAq.sqlite'
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3hh0k5d-SNzXTAMFsZ' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3hh0k5d-SNzXTAMFsZ.sqlite'
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3hh0k89-RVoN8mvGcQ' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3hh0k89-RVoN8mvGcQ.sqlite'
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3hh1p9w-dWBTo7k6qC' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3hh1p9w-dWBTo7k6qC.sqlite'
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3hh3ukx-2c8jjwnV85' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3hh3ukx-2c8jjwnV85.sqlite'
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3hhfffh-oQ6ihnHrpN' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3hhfffh-oQ6ihnHrpN.sqlite'
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3hhv6a1-IVyzFiZ1j6' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3hhv6a1-IVyzFiZ1j6.sqlite'
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3hk7te7-ZZrclzsdbP' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3hk7te7-ZZrclzsdbP.sqlite'
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3hk7tus-NbDFNleJHz' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3hk7tus-NbDFNleJHz.sqlite'
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3hk7txn-l9GB3WJMKT' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3hk7txn-l9GB3WJMKT.sqlite'
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3hk7tzu-yQ5iHF4cdn' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3hk7tzu-yQ5iHF4cdn.sqlite'
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3hk7u1h-hjcpClvB4h' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3hk7u1h-hjcpClvB4h.sqlite'
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3hk7uih-lRju2lRKKX' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3hk7uih-lRju2lRKKX.sqlite'
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3hk8evq-bf1w3XlTD7' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3hk8evq-bf1w3XlTD7.sqlite'
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3hk9aga-5x1aEPqhBi' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3hk9aga-5x1aEPqhBi.sqlite'
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3hkeour-cD9gIzhlQA' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3hkeour-cD9gIzhlQA.sqlite'
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3hkoypn-5pjRQkUvIL' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3hkoypn-5pjRQkUvIL.sqlite'
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3hpbe28-G6hPW4T0J7' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3hpbe28-G6hPW4T0J7.sqlite'
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3hpcdwv-gwFwfmkOGs' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3hpcdwv-gwFwfmkOGs.sqlite'
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3hpdrc4-8C7bx1JEvB' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3hpdrc4-8C7bx1JEvB.sqlite'
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3hu7kd0-JzN0Xz37Ty' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3hu7kd0-JzN0Xz37Ty.sqlite'
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3hu7orl-PdWEUf8oYe' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3hu7orl-PdWEUf8oYe.sqlite'
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3hu7pgz-Jv4v60FG18' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3hu7pgz-Jv4v60FG18.sqlite'
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3hu7rb8-FW8PdwCKFu' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3hu7rb8-FW8PdwCKFu.sqlite'
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3hu87n2-H2bBta9YP3' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3hu87n2-H2bBta9YP3.sqlite'
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3huciul-MI2kFdzXvI' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3huciul-MI2kFdzXvI.sqlite'
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3hufodj-T41C3SUvXE' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3hufodj-T41C3SUvXE.sqlite'
# Deleted file: C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3em462m-peAU7AP5jo.sqlite
# Deleted file: C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3hhv6a1-IVyzFiZ1j6.sqlite
# Deleted file: C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3eizo2a-pImzTCWsZI.sqlite
# Deleted file: C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3ezxdzn-6VtYbF8hpE.sqlite
# Deleted file: C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3hh1p9w-dWBTo7k6qC.sqlite
# Deleted file: C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3hk7uih-lRju2lRKKX.sqlite
# Deleted file: C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3elacrk-PTmLDCIw42.sqlite
# Deleted file: C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3ezsnhm-a7GYEzZPNf.sqlite
# Deleted file: C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3hpdrc4-8C7bx1JEvB.sqlite
# Deleted file: C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3em472r-q3DhZUD2m0.sqlite
# Deleted file: C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3em46ka-zczbvUtDGT.sqlite
# Deleted file: C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3hpcdwv-gwFwfmkOGs.sqlite
# Deleted file: C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3hpbe28-G6hPW4T0J7.sqlite
# Deleted file: C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3ej902f-6hhAGLT692.sqlite
# Deleted file: C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3hh0j5j-vFjcpMmfAq.sqlite
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3eiymbu-0xp5jiBpdI.sqlite' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7399-m3eiymbu-0xp5jiBpdI'
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3eiyogy-V88kCZA8PX.sqlite' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7399-m3eiyogy-V88kCZA8PX'
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3eiyz5p-JWFtYxC3Iz.sqlite' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7399-m3eiyz5p-JWFtYxC3Iz'
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3ej12ip-r95wPzmA17.sqlite' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7399-m3ej12ip-r95wPzmA17'
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3ej156r-duErjhvB31.sqlite' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7399-m3ej156r-duErjhvB31'
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3ejac8x-UjXCKYPsEm.sqlite' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7399-m3ejac8x-UjXCKYPsEm'
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3em41cj-PBTEckSJ5b.sqlite' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7399-m3em41cj-PBTEckSJ5b'
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3em4658-Wy8adTzqjd.sqlite' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7399-m3em4658-Wy8adTzqjd'
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3em477k-SV1Jok6QWh.sqlite' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7399-m3em477k-SV1Jok6QWh'
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3em4d5r-cOgJpoyZt8.sqlite' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7399-m3em4d5r-cOgJpoyZt8'
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3em94jn-IBVyhhvCE0.sqlite' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7399-m3em94jn-IBVyhhvCE0'
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3emhmpl-GFmekIOj5V.sqlite' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7399-m3emhmpl-GFmekIOj5V'
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3emlh6o-5KPM5OQ5mS.sqlite' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7399-m3emlh6o-5KPM5OQ5mS'
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3epbo6p-NOhT7IfbNZ.sqlite' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7399-m3epbo6p-NOhT7IfbNZ'
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3epbqu7-JSLeIr0XQe.sqlite' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7399-m3epbqu7-JSLeIr0XQe'
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3epbr8x-6duPHYrVZp.sqlite' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7399-m3epbr8x-6duPHYrVZp'
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3epbro3-T4U1KPViPO.sqlite' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7399-m3epbro3-T4U1KPViPO'
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3epbsfk-ridsrS8whP.sqlite' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7399-m3epbsfk-ridsrS8whP'
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3epbwqu-uvPJbrZrzQ.sqlite' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7399-m3epbwqu-uvPJbrZrzQ'
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3epdanu-xSdBgQ3YhK.sqlite' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7399-m3epdanu-xSdBgQ3YhK'
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3epmdhz-ZMyLB27s5X.sqlite' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7399-m3epmdhz-ZMyLB27s5X'
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3ezeaov-QjguzOTwHc.sqlite' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7399-m3ezeaov-QjguzOTwHc'
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3ezeofn-6pHlzJZ6r9.sqlite' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7399-m3ezeofn-6pHlzJZ6r9'
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3ezeons-dHVi0TtuGA.sqlite' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7399-m3ezeons-dHVi0TtuGA'
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3ezepfm-5OxUw08tUT.sqlite' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7399-m3ezepfm-5OxUw08tUT'
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3ezeprq-4btQbTSLKG.sqlite' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7399-m3ezeprq-4btQbTSLKG'
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3ezeq5v-vgdq6SUA9R.sqlite' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7399-m3ezeq5v-vgdq6SUA9R'
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3ezetpw-8FFUnG1Jp7.sqlite' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7399-m3ezetpw-8FFUnG1Jp7'
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3ezhv8l-GEjtLEela7.sqlite' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7399-m3ezhv8l-GEjtLEela7'
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3ezm4ad-XzX7pRFZhh.sqlite' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7399-m3ezm4ad-XzX7pRFZhh'
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3eznjxq-gMs5vLJHb5.sqlite' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7399-m3eznjxq-gMs5vLJHb5'
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3f0i4yx-QVn4tjBF7N.sqlite' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7399-m3f0i4yx-QVn4tjBF7N'
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3hdsc0k-YDtivu7Ods.sqlite' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7399-m3hdsc0k-YDtivu7Ods'
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3hdsosk-3IkdMFfjhn.sqlite' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7399-m3hdsosk-3IkdMFfjhn'
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3hdsp0f-vWPi61W6pM.sqlite' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7399-m3hdsp0f-vWPi61W6pM'
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3hdsp89-JNds0qY5Zr.sqlite' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7399-m3hdsp89-JNds0qY5Zr'
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3hdw736-wb5NwbmFfO.sqlite' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7399-m3hdw736-wb5NwbmFfO'
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3hdwune-tEbxHBTKAu.sqlite' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7399-m3hdwune-tEbxHBTKAu'
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3hh0ie9-pplhA1VbMu.sqlite' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7399-m3hh0ie9-pplhA1VbMu'
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3hh0iii-LeWRZMBN6h.sqlite' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7399-m3hh0iii-LeWRZMBN6h'
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3hh0imo-1BbY8bTQLj.sqlite' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7399-m3hh0imo-1BbY8bTQLj'
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3hh0ivg-uQbIWsBBSd.sqlite' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7399-m3hh0ivg-uQbIWsBBSd'
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3hh0k5d-SNzXTAMFsZ.sqlite' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7399-m3hh0k5d-SNzXTAMFsZ'
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3hh0k89-RVoN8mvGcQ.sqlite' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7399-m3hh0k89-RVoN8mvGcQ'
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3hh3ukx-2c8jjwnV85.sqlite' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7399-m3hh3ukx-2c8jjwnV85'
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3hhfffh-oQ6ihnHrpN.sqlite' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7399-m3hhfffh-oQ6ihnHrpN'
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3hk7te7-ZZrclzsdbP.sqlite' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7399-m3hk7te7-ZZrclzsdbP'
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3hk7tus-NbDFNleJHz.sqlite' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7399-m3hk7tus-NbDFNleJHz'
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3hk7txn-l9GB3WJMKT.sqlite' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7399-m3hk7txn-l9GB3WJMKT'
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3hk7tzu-yQ5iHF4cdn.sqlite' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7399-m3hk7tzu-yQ5iHF4cdn'
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3hk7u1h-hjcpClvB4h.sqlite' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7399-m3hk7u1h-hjcpClvB4h'
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3hk8evq-bf1w3XlTD7.sqlite' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7399-m3hk8evq-bf1w3XlTD7'
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3hk9aga-5x1aEPqhBi.sqlite' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7399-m3hk9aga-5x1aEPqhBi'
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3hkeour-cD9gIzhlQA.sqlite' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7399-m3hkeour-cD9gIzhlQA'
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3hkoypn-5pjRQkUvIL.sqlite' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7399-m3hkoypn-5pjRQkUvIL'
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3hu7kd0-JzN0Xz37Ty.sqlite' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7399-m3hu7kd0-JzN0Xz37Ty'
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3hu7orl-PdWEUf8oYe.sqlite' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7399-m3hu7orl-PdWEUf8oYe'
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3hu7pgz-Jv4v60FG18.sqlite' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7399-m3hu7pgz-Jv4v60FG18'
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3hu7rb8-FW8PdwCKFu.sqlite' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7399-m3hu7rb8-FW8PdwCKFu'
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3hu87n2-H2bBta9YP3.sqlite' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7399-m3hu87n2-H2bBta9YP3'
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3huciul-MI2kFdzXvI.sqlite' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7399-m3huciul-MI2kFdzXvI'
# Renamed 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7300-m3hufodj-T41C3SUvXE.sqlite' to 'C:\Users\Wren\Documents\SW Fall 2024\researchers\round 3\7399-m3hufodj-T41C3SUvXE'
# All specified operations are complete.
